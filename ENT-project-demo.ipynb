# %% [markdown]
# Solution-1

# %%
import pandas as pd
import json
data = pd.read_csv('D:\gowrishankar.p\Gen-AI\ENT Project\patient_history.csv')
print("The content of the file is:")
print(data['Patient_ID'])
# Out:
# The content of the file is:
# 0    100
# 1    101
# 2    102
# Name: Patient_ID, dtype: int64

# %%
import json
json_data = data.to_json(orient='records')
j_data = json.loads(json_data)
j_data
# Out:
# [{'Patient_ID': 100,
#   'Patient_Name': 'John',
#   'Phone': '000-8654',
#   'Address': 'NY',
#   'Age': 65,
#   'Main Cause': 'Ear Pain',
#   'Side': 'Left',
#   'Findings': 'Yes',
#   'Swelling': 'Yes',
#   'Pain': 'Moderate',
#   'Causing period': '3 Months',
#   'Other ': 'Heart disease',
#   'Diagonosis': None,
#   'Investigation': None,
#   'Treatment': None,
#   'Management': None,
#   'Summary': None},
#  {'Patient_ID': 101,
#   'Patient_Name': 'Maria',
#   'Phone': '000-8655',
#   'Address': 'MN',
#   'Age': 28,
#   'Main Cause': 'Ear Pain',
#   'Side': 'Right',
#   'Findings': 'Yes',
#   'Swelling': 'Odur',
#   'Pain': 'Heavy',
#   'Causing period': '2 Year',
#   'Other ': None,
#   'Diagonosis': None,
#   'Investigation': None,
#   'Treatment': None,
#   'Management': None,
#   'Summary': None},
#  {'Patient_ID': 102,
#   'Patient_Name': 'Britto',
#   'Phone': '000-8656',
#   'Address': 'CA',
#   'Age': 31,
#   'Main Cause': 'Ear Pain',
#   'Side': 'Left',
# ...

# %%
patient_id = 100  # Replace this with the actual patient_id you're looking for
filtered_data = [item for item in j_data if item['Patient_ID'] == patient_id]
filtered_data
# Out:
# [{'Patient_ID': 100,
#   'Patient_Name': 'John',
#   'Phone': '000-8654',
#   'Address': 'NY',
#   'Age': 65,
#   'Main Cause': 'Ear Pain',
#   'Side': 'Left',
#   'Findings': 'Yes',
#   'Swelling': 'Yes',
#   'Pain': 'Moderate',
#   'Causing period': '3 Months',
#   'Other ': 'Heart disease',
#   'Diagonosis': None,
#   'Investigation': None,
#   'Treatment': None,
#   'Management': None,
#   'Summary': None}]

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

#openai.api_key = "sk-API"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       3 from dotenv import load_dotenv
#       5 load_dotenv()
# ----> 6 os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
#       8 #openai.api_key = "sk-API"
#
# File c:\Program Files\Python310\lib\os.py:684, in _Environ.__setitem__(self, key, value)
#     682 def __setitem__(self, key, value):
#     683     key = self.encodekey(key)
# --> 684     value = self.encodevalue(value)
#     685     putenv(key, value)
#     686     self._data[key] = value
#
# File c:\Program Files\Python310\lib\os.py:742, in _createenviron.<locals>.check_str(value)
#     740 def check_str(value):
#     741     if not isinstance(value, str):
# --> 742         raise TypeError("str expected, not %s" % type(value).__name__)
#     743     return value
#
# TypeError: str expected, not NoneType

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        }
    ],
    model="gpt-3.5-turbo",
)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Example prompt and function call
#       2 prompt = "Write a code snippet to reverse a string in Python."
# ----> 3 response = openai.Completion.create(
#       4     engine="text-davinci-003",  # Replace with desired engine (optional)
#       5     prompt=prompt,
#       6     max_tokens=150,  # Adjust maximum response length (optional)
#       7     n=1,  # Number of desired responses (optional)
#       8     stop=None  # Optional stop sequence
#       9 )
#      11 # Access the generated text
#      12 generated_text = response.choices[0].text
#
# File ~\AppData\Roaming\Python\Python310\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ...
